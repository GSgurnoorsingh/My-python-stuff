# %%
from PIL import Image

# %%
mac=Image.open('images.jpeg')

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=284x178>

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac.size
# Out:
# (284, 178)

# %%
mac.filename
# Out:
# 'images.jpeg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %% [markdown]
# # Cropping images

# %%
mac.crop((0,0,10,20)) #This basically gave us the cropped part of the image from the top left corner
# Out:
# <PIL.Image.Image image mode=RGB size=10x20>

# %%
mac.size
# Out:
# (284, 178)

# %%
#Say if i want to crop 10% of width and 20% of height so we will crop like this
x=0
y=0

w=284/1
h=178/2

# %%
mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=284x89>

# %%
#Now lets say we want to grab from the bottom
#Now it will be done (ho hi jaega crop to ab)

# %%
#Now lets see copying and pasting a image

# %%
computer=mac.crop((x,y,w,h))

# %%
mac.paste(im=computer,box=(0,100))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=284x178>

# %%
#See above that we actually copy pasted mac into computer image

# %%
mac.rotate(90) #Just specify the degrees you want to rotate in the bracket
# Out:
# <PIL.Image.Image image mode=RGB size=284x178>
